# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
MergedDatasetsRenamed = pd.read_excel('../2progs/MergedDatasetsRenamed.xlsx',sheet_name='Sheet1',index_col = 0)

# %%
MergedDatasetsRenamed.head(5)
# Out:
#    hhid     s1q2_x  spend_tuitionfees  spend_textbooks  spend_exercisebooks  \
# 0    10  Village 1                0.0              0.0               2400.0
# 1    10  Village 1                0.0              0.0               2400.0
# 2    10  Village 1                0.0              0.0               2400.0
# 3    10  Village 1                0.0              0.0               2400.0
# 4    10  Village 1                0.0              0.0               2400.0
#
#    spend_schooluniform  spend_schoolboardingfees  spend_schooltransport  \
# 0                  0.0                    6000.0                 3000.0
# 1                  0.0                    6000.0                 3000.0
# 2                  0.0                    6000.0                 3000.0
# 3                  0.0                    6000.0                 3000.0
# 4                  0.0                    6000.0                 3000.0
#
#    spend_extratuition  spend_PTA  ...     hh_con  hh_con2011  hh_con2011_pd  \
# 0         2000.000061        0.0  ...  4679.5698    82.80928       2.722497
# 1         2000.000061        0.0  ...  4679.5698    82.80928       2.722497
# 2         2000.000061        0.0  ...  4679.5698    82.80928       2.722497
# 3         2000.000061        0.0  ...  4679.5698    82.80928       2.722497
# 4         2000.000061        0.0  ...  4679.5698    82.80928       2.722497
#
#    pline_ipl   poorIPL  pgi  spg  weight_y.1  popweight   Dataset2
# 0        1.9  Non-poor  0.0  0.0    5.557169  27.785843  Household
# 1        1.9  Non-poor  0.0  0.0    5.557169  27.785843  Household
# 2        1.9  Non-poor  0.0  0.0    5.557169  27.785843  Household
# 3        1.9  Non-poor  0.0  0.0    5.557169  27.785843  Household
# 4        1.9  Non-poor  0.0  0.0    5.557169  27.785843  Household
#
# [5 rows x 144 columns]

# %%
MergedDatasetsRenamed.describe()
# Out:
#                hhid  spend_tuitionfees  spend_textbooks  spend_exercisebooks  \
# count  18080.000000       18080.000000     18080.000000         18080.000000
# mean    2881.083075         483.579096       274.443437           496.192368
# std     1711.899022        3112.086816       844.785915           922.513144
# min       10.000000           0.000000         0.000000             0.000000
# 25%     1404.500000           0.000000         0.000000             0.000000
# 50%     2801.000000           0.000000         0.000000           180.000000
# 75%     4397.000000           0.000000         0.000000           600.000000
# max     6004.000000       48350.000980      9999.999878          8600.000000
#
#        spend_schooluniform  spend_schoolboardingfees  spend_schooltransport  \
# count         18080.000000              18080.000000           18080.000000
# mean            300.406527                519.651088             355.359513
# std            1039.178863               5716.036337            3207.206623
# min               0.000000                  0.000000               0.000000
# 25%               0.000000                  0.000000               0.000000
# 50%               0.000000                  0.000000               0.000000
# 75%               0.000000                  0.000000               0.000000
# max           14000.000000             100200.000000           72000.000000
#
#        spend_extratuition     spend_PTA  spend_pocketmoney  ...       hh_fcon  \
# count        18080.000000  18080.000000       18080.000000  ...  18080.000000
# mean            40.931785     19.302378         179.688606  ...   5220.971545
# std            372.584012    133.270265        1478.585277  ...   5816.500071
# min              0.000000      0.000000           0.000000  ...    280.630190
# 25%              0.000000      0.000000           0.000000  ...   2138.560100
# 50%              0.000000      0.000000           0.000000  ...   3456.051500
# 75%              0.000000      0.000000           0.000000  ...   6068.940400
# max           6000.000000   3000.000000       36000.000000  ...  62754.434000
#
#            hh_nfcon        hh_con    hh_con2011  hh_con2011_pd     pline_ipl  \
# count  18080.000000  18080.000000  18080.000000   18080.000000  1.808000e+04
# mean    1150.272287   6371.243831    112.744999       3.706685  1.900000e+00
# std     1880.082360   7316.670959    129.475195       4.256719  6.388400e-13
# min       30.422174    409.410490      7.244894       0.238188  1.900000e+00
# 25%      347.809720   2622.582300     46.409000       1.525775  1.900000e+00
# 50%      632.616210   4206.944300     74.445732       2.447531  1.900000e+00
# 75%     1275.704600   7178.627400    127.032390       4.176407  1.900000e+00
# max    26267.102000  89021.539000   1575.317600      51.791267  1.900000e+00
#
#                 pgi           spg    weight_y.1     popweight
# count  18080.000000  18080.000000  1.808000e+04  18080.000000
# mean       0.126914      0.053089  5.557169e+00     32.314873
# std        0.192312      0.107686  2.041090e-12     17.213481
# min        0.000000      0.000000  5.557169e+00      5.557169
# 25%        0.000000      0.000000  5.557169e+00     22.228674
# 50%        0.000000      0.000000  5.557169e+00     33.343010
# 75%        0.233719      0.054625  5.557169e+00     44.457348
# max        0.874638      0.764991  5.557169e+00    116.700540
#
# [8 rows x 75 columns]

# %%
#Creating Dummy Variables for Household and Food Data Sets 
MergedDatasetsRenamed= pd.get_dummies(MergedDatasetsRenamed, columns=["own_radio",
                          "own_television", "drinkingwater_insufficientquanities", "own_satelitedish", "own_smartphone",
                          "own_refrigerator",  "own_table", "own_bed", "own_mattress", 
                         "own_mosquitonet", "own_fan", "own_bicycle", "own_motorcycle", 
                        "own_car", "own_generator", "own_solarpanels", "own_kerosenestove",
                          "own_charcoaljiko", "own_wheelbarrow","own_ironfencing", 
                          "own_farmanimals","relatives_abroad","relatives_outsidekenya", 
                          "own_bankaccount","borrowedfrom_sources12mo", "borrowedfrom_bank12mo", 
                          "borrowedfrom_community", "borrowedfrom_familyorfriends12mo", "remittances_abroad", 
                         "purchased_insurance", "childunder5_death5yrs", "sellhhgoods_lackfood", 
                           "healthandeduc_reduction",  "sellassets_lackfood",  "spendsavings:lackfood", 
                          "borrowmoneyfood_lackfood", "sellhouseland_lackfood", "withdrawchildrenschool_lackfood", 
                         "sellanimals:lackfood", "sellfemaleanimal_last", "beg_lackfood", "payrent_dwelling", 
                        "hh_purchasedfood7d", 'foodwasfree'])
MergedDatasetsRenamed
# Out:
#        hhid     s1q2_x  spend_tuitionfees  spend_textbooks  \
# 0        10  Village 1                0.0              0.0
# 1        10  Village 1                0.0              0.0
# 2        10  Village 1                0.0              0.0
# 3        10  Village 1                0.0              0.0
# 4        10  Village 1                0.0              0.0
# ...     ...        ...                ...              ...
# 18075  6004  Village 3                0.0              0.0
# 18076  6004  Village 3                0.0              0.0
# 18077  6004  Village 3                0.0              0.0
# 18078  6004  Village 3                0.0              0.0
# 18079  6004  Village 3                0.0              0.0
#
#        spend_exercisebooks  spend_schooluniform  spend_schoolboardingfees  \
# 0              2400.000000                  0.0                    6000.0
# 1              2400.000000                  0.0                    6000.0
# 2              2400.000000                  0.0                    6000.0
# 3              2400.000000                  0.0                    6000.0
# 4              2400.000000                  0.0                    6000.0
# ...                    ...                  ...                       ...
# 18075          1000.000031                  0.0                       0.0
# 18076          1000.000031                  0.0                       0.0
# 18077          1000.000031                  0.0                       0.0
# 18078          1000.000031                  0.0                       0.0
# 18079          1000.000031                  0.0                       0.0
#
#        spend_schooltransport  spend_extratuition  spend_PTA  ...  \
# 0                     3000.0         2000.000061        0.0  ...
# 1                     3000.0         2000.000061        0.0  ...
# 2                     3000.0         2000.000061        0.0  ...
# 3                     3000.0         2000.000061        0.0  ...
# 4                     3000.0         2000.000061        0.0  ...
# ...                      ...                 ...        ...  ...
# 18075                    0.0            0.000000        0.0  ...
# 18076                    0.0            0.000000        0.0  ...
# 18077                    0.0            0.000000        0.0  ...
# 18078                    0.0            0.000000        0.0  ...
# 18079                    0.0            0.000000        0.0  ...
#
#        sellfemaleanimal_last_Yes  beg_lackfood_No  beg_lackfood_Yes  \
# 0                              0                1                 0
# 1                              0                1                 0
# 2                              0                1                 0
# 3                              0                1                 0
# 4                              0                1                 0
# ...                          ...              ...               ...
# 18075                          0                1                 0
# 18076                          0                1                 0
# 18077                          0                1                 0
# 18078                          0                1                 0
# 18079                          0                1                 0
#
#        payrent_dwelling_No  hh_purchasedfood7d_No  hh_purchasedfood7d_Yes  \
# 0                        1                      0                       1
# 1                        1                      0                       1
# 2                        1                      0                       1
# 3                        1                      0                       1
# 4                        1                      0                       1
# ...                    ...                    ...                     ...
# 18075                    1                      0                       1
# 18076                    1                      0                       1
# 18077                    1                      0                       1
# 18078                    1                      0                       1
# 18079                    1                      0                       1
#
#        foodwasfree_Don't Know  foodwasfree_No  foodwasfree_Refused to Respond  \
# 0                           0               0                               0
# 1                           0               0                               0
# 2                           0               0                               0
# 3                           0               0                               0
# 4                           0               0                               0
# ...                       ...             ...                             ...
# 18075                       0               0                               0
# 18076                       0               0                               0
# 18077                       0               0                               0
# 18078                       0               1                               0
# 18079                       0               0                               0
#
#        foodwasfree_Yes
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 18075                0
# 18076                0
# 18077                1
# 18078                0
# 18079                1
#
# [18080 rows x 188 columns]

# %%
#Outlier Treatment 
MergedDatasetsRenamed['amountfood_purchased7d'] = np.where(MergedDatasetsRenamed['amountfood_purchased7d'] > 80, 80,MergedDatasetsRenamed['amountfood_purchased7d'])

# %%
#Histogram by setting cutoff at 80 
MergedDatasetsRenamed.amountfood_purchased7d.hist()

# %%
#Box Plot Representation by using a cutoff at 80 
boxplot = MergedDatasetsRenamed.boxplot(column=['amountfood_purchased7d'])

# %%
#Outlier correction for food spent in local currency 
MergedDatasetsRenamed['foodspent_localcurrecny'] = np.where(MergedDatasetsRenamed['foodspent_localcurrecny'] > 600, 600, MergedDatasetsRenamed['foodspent_localcurrecny'])

# %%
#Histogram using 600 as the cuttoff
MergedDatasetsRenamed.foodspent_localcurrecny.hist()

# %%
#boxplot using 600 at the cutoff 
boxplot = MergedDatasetsRenamed.boxplot(column=['foodspent_localcurrecny'])

# %%
#Outliers for Food Cumsumed in past 7 days 
MergedDatasetsRenamed['foodconsumed7d'] = np.where(MergedDatasetsRenamed['foodconsumed7d'] > 30, 30, MergedDatasetsRenamed['foodconsumed7d'])

# %%
#Histogram using 30 as the cutoff point 
MergedDatasetsRenamed.foodconsumed7d.hist()

# %%
boxplot = MergedDatasetsRenamed.boxplot(column=['foodconsumed7d'])

# %%
MergedDatasetsRenamed.describe()
# Out:
#                hhid  spend_tuitionfees  spend_textbooks  spend_exercisebooks  \
# count  18080.000000       18080.000000     18080.000000         18080.000000
# mean    2881.083075         483.579096       274.443437           496.192368
# std     1711.899022        3112.086816       844.785915           922.513144
# min       10.000000           0.000000         0.000000             0.000000
# 25%     1404.500000           0.000000         0.000000             0.000000
# 50%     2801.000000           0.000000         0.000000           180.000000
# 75%     4397.000000           0.000000         0.000000           600.000000
# max     6004.000000       48350.000980      9999.999878          8600.000000
#
#        spend_schooluniform  spend_schoolboardingfees  spend_schooltransport  \
# count         18080.000000              18080.000000           18080.000000
# mean            300.406527                519.651088             355.359513
# std            1039.178863               5716.036337            3207.206623
# min               0.000000                  0.000000               0.000000
# 25%               0.000000                  0.000000               0.000000
# 50%               0.000000                  0.000000               0.000000
# 75%               0.000000                  0.000000               0.000000
# max           14000.000000             100200.000000           72000.000000
#
#        spend_extratuition     spend_PTA  spend_pocketmoney  ...  \
# count        18080.000000  18080.000000       18080.000000  ...
# mean            40.931785     19.302378         179.688606  ...
# std            372.584012    133.270265        1478.585277  ...
# min              0.000000      0.000000           0.000000  ...
# 25%              0.000000      0.000000           0.000000  ...
# 50%              0.000000      0.000000           0.000000  ...
# 75%              0.000000      0.000000           0.000000  ...
# max           6000.000000   3000.000000       36000.000000  ...
#
#        sellfemaleanimal_last_Yes  beg_lackfood_No  beg_lackfood_Yes  \
# count               18080.000000     18080.000000      18080.000000
# mean                    0.044580         0.866372          0.133628
# std                     0.206385         0.340262          0.340262
# min                     0.000000         0.000000          0.000000
# 25%                     0.000000         1.000000          0.000000
# 50%                     0.000000         1.000000          0.000000
# 75%                     0.000000         1.000000          0.000000
# max                     1.000000         1.000000          1.000000
#
#        payrent_dwelling_No  hh_purchasedfood7d_No  hh_purchasedfood7d_Yes  \
# count              18080.0           18080.000000            18080.000000
# mean                   1.0               0.159624                0.840376
# std                    0.0               0.366267                0.366267
# min                    1.0               0.000000                0.000000
# 25%                    1.0               0.000000                1.000000
# 50%                    1.0               0.000000                1.000000
# 75%                    1.0               0.000000                1.000000
# max                    1.0               1.000000                1.000000
#
#        foodwasfree_Don't Know  foodwasfree_No  foodwasfree_Refused to Respond  \
# count            18080.000000    18080.000000                    18080.000000
# mean                 0.001217        0.135288                        0.000221
# std                  0.034863        0.342040                        0.014873
# min                  0.000000        0.000000                        0.000000
# 25%                  0.000000        0.000000                        0.000000
# 50%                  0.000000        0.000000                        0.000000
# 75%                  0.000000        0.000000                        0.000000
# max                  1.000000        1.000000                        1.000000
#
#        foodwasfree_Yes
# count     18080.000000
# mean          0.720465
# std           0.448783
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           1.000000
# max           1.000000
#
# [8 rows x 163 columns]
